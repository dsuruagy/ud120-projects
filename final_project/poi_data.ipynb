# %%
import pickle
import pandas as pd

features_list = ['poi','salary', 'deferral_payments', 'total_payments', 'loan_advances', 'bonus',
                   'restricted_stock_deferred', 'deferred_income', 'total_stock_value', 'expenses',
                   'exercised_stock_options', 'other', 'long_term_incentive', 'restricted_stock',
                   'director_fees', 'to_messages', 'from_poi_to_this_person', 'from_messages',
                   'from_this_person_to_poi', 'shared_receipt_with_poi']

with open("final_project_dataset.pkl", "r") as data_file:
    data_dict = pickle.load(data_file)

# Remove outlier
data_dict.pop('TOTAL')

df = pd.DataFrame(data_dict).transpose()
df.drop('email_address', inplace=True, axis=1)

# converting values to numeric format
df[features_list] = df[features_list].apply(pd.to_numeric, errors ='coerce')

# filling NaN as zero
#df.fillna(0, inplace=True)



from_poi_rate = 'from_poi_rate'
shared_poi_rate = 'shared_poi_rate'
to_poi_rate = 'to_poi_rate'

df[from_poi_rate] = df['from_this_person_to_poi']/df['from_messages']
df[shared_poi_rate] = df['shared_receipt_with_poi']/df['to_messages']
df[to_poi_rate] = df['from_poi_to_this_person']/df['to_messages']
df.fillna(0, inplace=True)
my_dataset = df.to_dict(orient='index')
features_list.extend([from_poi_rate, shared_poi_rate, to_poi_rate])

#my_dataset = data_dict

#df[df['poi'] == True].head(5)
df.head(5)

my_dataset
# Out:
# {'ALLEN PHILLIP K': {'bonus': 4175000.0,
#   'deferral_payments': 2869717.0,
#   'deferred_income': -3081055.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 1729541.0,
#   'expenses': 13868.0,
#   'from_messages': 2195.0,
#   'from_poi_rate': 0.029612756264236904,
#   'from_poi_to_this_person': 47.0,
#   'from_this_person_to_poi': 65.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 304805.0,
#   'other': 152.0,
#   'poi': False,
#   'restricted_stock': 126027.0,
#   'restricted_stock_deferred': -126027.0,
#   'salary': 201955.0,
#   'shared_poi_rate': 0.4848380427291523,
#   'shared_receipt_with_poi': 1407.0,
#   'to_messages': 2902.0,
#   'to_poi_rate': 0.016195727084769126,
#   'total_payments': 4484442.0,
#   'total_stock_value': 1729541.0},
#  'BADUM JAMES P': {'bonus': 0.0,
#   'deferral_payments': 178980.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 257817.0,
#   'expenses': 3486.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 182466.0,
#   'total_stock_value': 257817.0},
#  'BANNANTINE JAMES M': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -5104.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 4046157.0,
#   'expenses': 56301.0,
#   'from_messages': 29.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 39.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 864523.0,
#   'poi': False,
#   'restricted_stock': 1757552.0,
#   'restricted_stock_deferred': -560222.0,
#   'salary': 477.0,
#   'shared_poi_rate': 0.8215547703180212,
#   'shared_receipt_with_poi': 465.0,
#   'to_messages': 566.0,
#   'to_poi_rate': 0.06890459363957598,
#   'total_payments': 916197.0,
#   'total_stock_value': 5243487.0},
#  'BAXTER JOHN C': {'bonus': 1200000.0,
#   'deferral_payments': 1295738.0,
#   'deferred_income': -1386055.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 6680544.0,
#   'expenses': 11200.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 1586055.0,
#   'other': 2660303.0,
#   'poi': False,
#   'restricted_stock': 3942714.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 267102.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 5634343.0,
#   'total_stock_value': 10623258.0},
#  'BAY FRANKLIN R': {'bonus': 400000.0,
#   'deferral_payments': 260455.0,
#   'deferred_income': -201641.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 129142.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 69.0,
#   'poi': False,
#   'restricted_stock': 145796.0,
#   'restricted_stock_deferred': -82782.0,
#   'salary': 239671.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 827696.0,
#   'total_stock_value': 63014.0},
#  'BAZELIDES PHILIP J': {'bonus': 0.0,
#   'deferral_payments': 684694.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 1599641.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 93750.0,
#   'other': 874.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 80818.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 860136.0,
#   'total_stock_value': 1599641.0},
#  'BECK SALLY W': {'bonus': 700000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 37172.0,
#   'from_messages': 4343.0,
#   'from_poi_rate': 0.08887865530739121,
#   'from_poi_to_this_person': 144.0,
#   'from_this_person_to_poi': 386.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 566.0,
#   'poi': False,
#   'restricted_stock': 126027.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 231330.0,
#   'shared_poi_rate': 0.36076555023923446,
#   'shared_receipt_with_poi': 2639.0,
#   'to_messages': 7315.0,
#   'to_poi_rate': 0.01968557758031442,
#   'total_payments': 969068.0,
#   'total_stock_value': 126027.0},
#  'BELDEN TIMOTHY N': {'bonus': 5249999.0,
#   'deferral_payments': 2144013.0,
#   'deferred_income': -2334434.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 953136.0,
#   'expenses': 17355.0,
#   'from_messages': 484.0,
#   'from_poi_rate': 0.2231404958677686,
#   'from_poi_to_this_person': 228.0,
#   'from_this_person_to_poi': 108.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 210698.0,
#   'poi': True,
#   'restricted_stock': 157569.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 213999.0,
#   'shared_poi_rate': 0.6909022650481792,
#   'shared_receipt_with_poi': 5521.0,
#   'to_messages': 7991.0,
#   'to_poi_rate': 0.028532098610937303,
#   'total_payments': 5501630.0,
#   'total_stock_value': 1110705.0},
#  'BELFER ROBERT': {'bonus': 0.0,
#   'deferral_payments': -102500.0,
#   'deferred_income': 0.0,
#   'director_fees': 3285.0,
#   'exercised_stock_options': 3285.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 44093.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 102500.0,
#   'total_stock_value': -44093.0},
#  'BERBERIAN DAVID': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 1624396.0,
#   'expenses': 11892.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 869220.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 216582.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 228474.0,
#   'total_stock_value': 2493616.0},
#  'BERGSIEKER RICHARD P': {'bonus': 250000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -485813.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 59175.0,
#   'from_messages': 59.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 4.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 180250.0,
#   'other': 427316.0,
#   'poi': False,
#   'restricted_stock': 659249.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 187922.0,
#   'shared_poi_rate': 0.608355091383812,
#   'shared_receipt_with_poi': 233.0,
#   'to_messages': 383.0,
#   'to_poi_rate': 0.010443864229765013,
#   'total_payments': 618850.0,
#   'total_stock_value': 659249.0},
#  'BHATNAGAR SANJAY': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 137864.0,
#   'exercised_stock_options': 2604490.0,
#   'expenses': 0.0,
#   'from_messages': 29.0,
#   'from_poi_rate': 0.034482758620689655,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 1.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 137864.0,
#   'poi': False,
#   'restricted_stock': -2604490.0,
#   'restricted_stock_deferred': 15456290.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.8852772466539197,
#   'shared_receipt_with_poi': 463.0,
#   'to_messages': 523.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 15456290.0,
#   'total_stock_value': 0.0},
#  'BIBI PHILIPPE A': {'bonus': 1000000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 1465734.0,
#   'expenses': 38559.0,
#   'from_messages': 40.0,
#   'from_poi_rate': 0.2,
#   'from_poi_to_this_person': 23.0,
#   'from_this_person_to_poi': 8.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 369721.0,
#   'other': 425688.0,
#   'poi': False,
#   'restricted_stock': 378082.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 213625.0,
#   'shared_poi_rate': 0.8313627878033603,
#   'shared_receipt_with_poi': 1336.0,
#   'to_messages': 1607.0,
#   'to_poi_rate': 0.01431238332296204,
#   'total_payments': 2047593.0,
#   'total_stock_value': 1843816.0},
#  'BLACHMAN JEREMY M': {'bonus': 850000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 765313.0,
#   'expenses': 84208.0,
#   'from_messages': 14.0,
#   'from_poi_rate': 0.14285714285714285,
#   'from_poi_to_this_person': 25.0,
#   'from_this_person_to_poi': 2.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 831809.0,
#   'other': 272.0,
#   'poi': False,
#   'restricted_stock': 189041.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 248546.0,
#   'shared_poi_rate': 0.9397979797979797,
#   'shared_receipt_with_poi': 2326.0,
#   'to_messages': 2475.0,
#   'to_poi_rate': 0.010101010101010102,
#   'total_payments': 2014835.0,
#   'total_stock_value': 954354.0},
#  'BLAKE JR. NORMAN P': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -113784.0,
#   'director_fees': 113784.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 1279.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 1279.0,
#   'total_stock_value': 0.0},
#  'BOWEN JR RAYMOND M': {'bonus': 1350000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -833.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 65907.0,
#   'from_messages': 27.0,
#   'from_poi_rate': 0.5555555555555556,
#   'from_poi_to_this_person': 140.0,
#   'from_this_person_to_poi': 15.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 974293.0,
#   'other': 1621.0,
#   'poi': True,
#   'restricted_stock': 252055.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 278601.0,
#   'shared_poi_rate': 0.8573735199138859,
#   'shared_receipt_with_poi': 1593.0,
#   'to_messages': 1858.0,
#   'to_poi_rate': 0.07534983853606028,
#   'total_payments': 2669589.0,
#   'total_stock_value': 252055.0},
#  'BROWN MICHAEL': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 49288.0,
#   'from_messages': 41.0,
#   'from_poi_rate': 0.024390243902439025,
#   'from_poi_to_this_person': 13.0,
#   'from_this_person_to_poi': 1.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.5121130551816958,
#   'shared_receipt_with_poi': 761.0,
#   'to_messages': 1486.0,
#   'to_poi_rate': 0.008748317631224764,
#   'total_payments': 49288.0,
#   'total_stock_value': 0.0},
#  'BUCHANAN HAROLD G': {'bonus': 500000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 825464.0,
#   'expenses': 600.0,
#   'from_messages': 125.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 304805.0,
#   'other': 1215.0,
#   'poi': False,
#   'restricted_stock': 189041.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 248017.0,
#   'shared_poi_rate': 0.021139705882352942,
#   'shared_receipt_with_poi': 23.0,
#   'to_messages': 1088.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 1054637.0,
#   'total_stock_value': 1014505.0},
#  'BUTTS ROBERT H': {'bonus': 750000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -75000.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 9410.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 175000.0,
#   'other': 150656.0,
#   'poi': False,
#   'restricted_stock': 417619.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 261516.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 1271582.0,
#   'total_stock_value': 417619.0},
#  'BUY RICHARD B': {'bonus': 900000.0,
#   'deferral_payments': 649584.0,
#   'deferred_income': -694862.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 2542813.0,
#   'expenses': 0.0,
#   'from_messages': 1053.0,
#   'from_poi_rate': 0.06742640075973409,
#   'from_poi_to_this_person': 156.0,
#   'from_this_person_to_poi': 71.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 769862.0,
#   'other': 400572.0,
#   'poi': False,
#   'restricted_stock': 901657.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 330546.0,
#   'shared_poi_rate': 0.6622196991200682,
#   'shared_receipt_with_poi': 2333.0,
#   'to_messages': 3523.0,
#   'to_poi_rate': 0.04428044280442804,
#   'total_payments': 2355702.0,
#   'total_stock_value': 3444470.0},
#  'CALGER CHRISTOPHER F': {'bonus': 1250000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -262500.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 35818.0,
#   'from_messages': 144.0,
#   'from_poi_rate': 0.1736111111111111,
#   'from_poi_to_this_person': 199.0,
#   'from_this_person_to_poi': 25.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 375304.0,
#   'other': 486.0,
#   'poi': True,
#   'restricted_stock': 126027.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 240189.0,
#   'shared_poi_rate': 0.8421862971516552,
#   'shared_receipt_with_poi': 2188.0,
#   'to_messages': 2598.0,
#   'to_poi_rate': 0.07659738260200154,
#   'total_payments': 1639297.0,
#   'total_stock_value': 126027.0},
#  'CARTER REBECCA C': {'bonus': 300000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -159792.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 0.0,
#   'from_messages': 15.0,
#   'from_poi_rate': 0.4666666666666667,
#   'from_poi_to_this_person': 29.0,
#   'from_this_person_to_poi': 7.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 75000.0,
#   'other': 540.0,
#   'poi': False,
#   'restricted_stock': 307301.0,
#   'restricted_stock_deferred': -307301.0,
#   'salary': 261809.0,
#   'shared_poi_rate': 0.6282051282051282,
#   'shared_receipt_with_poi': 196.0,
#   'to_messages': 312.0,
#   'to_poi_rate': 0.09294871794871795,
#   'total_payments': 477557.0,
#   'total_stock_value': 0.0},
#  'CAUSEY RICHARD A': {'bonus': 1000000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -235000.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 30674.0,
#   'from_messages': 49.0,
#   'from_poi_rate': 0.24489795918367346,
#   'from_poi_to_this_person': 58.0,
#   'from_this_person_to_poi': 12.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 350000.0,
#   'other': 307895.0,
#   'poi': True,
#   'restricted_stock': 2502063.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 415189.0,
#   'shared_poi_rate': 0.837737843551797,
#   'shared_receipt_with_poi': 1585.0,
#   'to_messages': 1892.0,
#   'to_poi_rate': 0.0306553911205074,
#   'total_payments': 1868758.0,
#   'total_stock_value': 2502063.0},
#  'CHAN RONNIE': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -98784.0,
#   'director_fees': 98784.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 32460.0,
#   'restricted_stock_deferred': -32460.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 0.0,
#   'total_stock_value': 0.0},
#  'CHRISTODOULOU DIOMEDES': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 5127155.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 950730.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 0.0,
#   'total_stock_value': 6077885.0},
#  'CLINE KENNETH W': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 662086.0,
#   'restricted_stock_deferred': -472568.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 0.0,
#   'total_stock_value': 189518.0},
#  'COLWELL WESLEY': {'bonus': 1200000.0,
#   'deferral_payments': 27610.0,
#   'deferred_income': -144062.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 16514.0,
#   'from_messages': 40.0,
#   'from_poi_rate': 0.275,
#   'from_poi_to_this_person': 240.0,
#   'from_this_person_to_poi': 11.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 101740.0,
#   'poi': True,
#   'restricted_stock': 698242.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 288542.0,
#   'shared_poi_rate': 0.6439135381114903,
#   'shared_receipt_with_poi': 1132.0,
#   'to_messages': 1758.0,
#   'to_poi_rate': 0.13651877133105803,
#   'total_payments': 1490344.0,
#   'total_stock_value': 698242.0},
#  'CORDES WILLIAM R': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 651850.0,
#   'expenses': 0.0,
#   'from_messages': 12.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 10.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 386335.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.07591623036649214,
#   'shared_receipt_with_poi': 58.0,
#   'to_messages': 764.0,
#   'to_poi_rate': 0.013089005235602094,
#   'total_payments': 0.0,
#   'total_stock_value': 1038185.0},
#  'COX DAVID': {'bonus': 800000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -41250.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 117551.0,
#   'expenses': 27861.0,
#   'from_messages': 33.0,
#   'from_poi_rate': 0.12121212121212122,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 4.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 494.0,
#   'poi': False,
#   'restricted_stock': 378082.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 314288.0,
#   'shared_poi_rate': 0.696078431372549,
#   'shared_receipt_with_poi': 71.0,
#   'to_messages': 102.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 1101393.0,
#   'total_stock_value': 495633.0},
#  'CUMBERLAND MICHAEL S': {'bonus': 325000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 22344.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 275000.0,
#   'other': 713.0,
#   'poi': False,
#   'restricted_stock': 207940.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 184899.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 807956.0,
#   'total_stock_value': 207940.0},
#  'DEFFNER JOSEPH M': {'bonus': 600000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 17378.0,
#   'expenses': 41626.0,
#   'from_messages': 74.0,
#   'from_poi_rate': 0.05405405405405406,
#   'from_poi_to_this_person': 115.0,
#   'from_this_person_to_poi': 4.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 335349.0,
#   'other': 25553.0,
#   'poi': False,
#   'restricted_stock': 141833.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 206121.0,
#   'shared_poi_rate': 0.773109243697479,
#   'shared_receipt_with_poi': 552.0,
#   'to_messages': 714.0,
#   'to_poi_rate': 0.16106442577030813,
#   'total_payments': 1208649.0,
#   'total_stock_value': 159211.0},
#  'DELAINEY DAVID W': {'bonus': 3000000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 2291113.0,
#   'expenses': 86174.0,
#   'from_messages': 3069.0,
#   'from_poi_rate': 0.198435972629521,
#   'from_poi_to_this_person': 66.0,
#   'from_this_person_to_poi': 609.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 1294981.0,
#   'other': 1661.0,
#   'poi': True,
#   'restricted_stock': 1323148.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 365163.0,
#   'shared_poi_rate': 0.6779825412221144,
#   'shared_receipt_with_poi': 2097.0,
#   'to_messages': 3093.0,
#   'to_poi_rate': 0.02133850630455868,
#   'total_payments': 4747979.0,
#   'total_stock_value': 3614261.0},
#  'DERRICK JR. JAMES V': {'bonus': 800000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -1284000.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 8831913.0,
#   'expenses': 51124.0,
#   'from_messages': 909.0,
#   'from_poi_rate': 0.022002200220022004,
#   'from_poi_to_this_person': 64.0,
#   'from_this_person_to_poi': 20.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 484000.0,
#   'other': 7482.0,
#   'poi': False,
#   'restricted_stock': 1787380.0,
#   'restricted_stock_deferred': -1787380.0,
#   'salary': 492375.0,
#   'shared_poi_rate': 0.6423658872077029,
#   'shared_receipt_with_poi': 1401.0,
#   'to_messages': 2181.0,
#   'to_poi_rate': 0.029344337459880788,
#   'total_payments': 550981.0,
#   'total_stock_value': 8831913.0},
#  'DETMERING TIMOTHY J': {'bonus': 425000.0,
#   'deferral_payments': 875307.0,
#   'deferred_income': -775241.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 2027865.0,
#   'expenses': 52255.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 415657.0,
#   'other': 1105.0,
#   'poi': False,
#   'restricted_stock': 315068.0,
#   'restricted_stock_deferred': -315068.0,
#   'salary': 210500.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 1204583.0,
#   'total_stock_value': 2027865.0},
#  'DIETRICH JANET R': {'bonus': 600000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 1550019.0,
#   'expenses': 3475.0,
#   'from_messages': 63.0,
#   'from_poi_rate': 0.2222222222222222,
#   'from_poi_to_this_person': 305.0,
#   'from_this_person_to_poi': 14.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 556416.0,
#   'other': 473.0,
#   'poi': False,
#   'restricted_stock': 315068.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 250100.0,
#   'shared_poi_rate': 0.73950233281493,
#   'shared_receipt_with_poi': 1902.0,
#   'to_messages': 2572.0,
#   'to_poi_rate': 0.11858475894245724,
#   'total_payments': 1410464.0,
#   'total_stock_value': 1865087.0},
#  'DIMICHELE RICHARD G': {'bonus': 1000000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 8191755.0,
#   'expenses': 35812.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 694862.0,
#   'other': 374689.0,
#   'poi': False,
#   'restricted_stock': 126027.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 262788.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 2368151.0,
#   'total_stock_value': 8317782.0},
#  'DODSON KEITH': {'bonus': 70000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 28164.0,
#   'from_messages': 14.0,
#   'from_poi_rate': 0.21428571428571427,
#   'from_poi_to_this_person': 10.0,
#   'from_this_person_to_poi': 3.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 774.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 221003.0,
#   'shared_poi_rate': 0.6477272727272727,
#   'shared_receipt_with_poi': 114.0,
#   'to_messages': 176.0,
#   'to_poi_rate': 0.056818181818181816,
#   'total_payments': 319941.0,
#   'total_stock_value': 0.0},
#  'DONAHUE JR JEFFREY M': {'bonus': 800000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -300000.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 765920.0,
#   'expenses': 96268.0,
#   'from_messages': 22.0,
#   'from_poi_rate': 0.5,
#   'from_poi_to_this_person': 188.0,
#   'from_this_person_to_poi': 11.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 891.0,
#   'poi': False,
#   'restricted_stock': 315068.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 278601.0,
#   'shared_poi_rate': 0.892485549132948,
#   'shared_receipt_with_poi': 772.0,
#   'to_messages': 865.0,
#   'to_poi_rate': 0.21734104046242775,
#   'total_payments': 875760.0,
#   'total_stock_value': 1080988.0},
#  'DUNCAN JOHN H': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -25000.0,
#   'director_fees': 102492.0,
#   'exercised_stock_options': 371750.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 77492.0,
#   'total_stock_value': 371750.0},
#  'DURAN WILLIAM D': {'bonus': 750000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 1451869.0,
#   'expenses': 25785.0,
#   'from_messages': 12.0,
#   'from_poi_rate': 0.25,
#   'from_poi_to_this_person': 106.0,
#   'from_this_person_to_poi': 3.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 1105218.0,
#   'other': 1568.0,
#   'poi': False,
#   'restricted_stock': 189041.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 210692.0,
#   'shared_poi_rate': 0.6626106194690266,
#   'shared_receipt_with_poi': 599.0,
#   'to_messages': 904.0,
#   'to_poi_rate': 0.1172566371681416,
#   'total_payments': 2093263.0,
#   'total_stock_value': 1640910.0},
#  'ECHOLS JOHN B': {'bonus': 200000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 601438.0,
#   'expenses': 21530.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 2234774.0,
#   'other': 53775.0,
#   'poi': False,
#   'restricted_stock': 407503.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 182245.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 2692324.0,
#   'total_stock_value': 1008941.0},
#  'ELLIOTT STEVEN': {'bonus': 350000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -400729.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 4890344.0,
#   'expenses': 78552.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 12961.0,
#   'poi': False,
#   'restricted_stock': 1788391.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 170941.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 211725.0,
#   'total_stock_value': 6678735.0},
#  'FALLON JAMES B': {'bonus': 2500000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 940257.0,
#   'expenses': 95924.0,
#   'from_messages': 75.0,
#   'from_poi_rate': 0.49333333333333335,
#   'from_poi_to_this_person': 42.0,
#   'from_this_person_to_poi': 37.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 374347.0,
#   'other': 401481.0,
#   'poi': False,
#   'restricted_stock': 1392142.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 304588.0,
#   'shared_poi_rate': 0.913960113960114,
#   'shared_receipt_with_poi': 1604.0,
#   'to_messages': 1755.0,
#   'to_poi_rate': 0.023931623931623933,
#   'total_payments': 3676340.0,
#   'total_stock_value': 2332399.0},
#  'FASTOW ANDREW S': {'bonus': 1300000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -1386055.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 55921.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 1736055.0,
#   'other': 277464.0,
#   'poi': True,
#   'restricted_stock': 1794412.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 440698.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 2424083.0,
#   'total_stock_value': 1794412.0},
#  'FITZGERALD JAY L': {'bonus': 350000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 664461.0,
#   'expenses': 23870.0,
#   'from_messages': 16.0,
#   'from_poi_rate': 0.5,
#   'from_poi_to_this_person': 1.0,
#   'from_this_person_to_poi': 8.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 556416.0,
#   'other': 285414.0,
#   'poi': False,
#   'restricted_stock': 956775.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 199157.0,
#   'shared_poi_rate': 0.7724358974358975,
#   'shared_receipt_with_poi': 723.0,
#   'to_messages': 936.0,
#   'to_poi_rate': 0.0010683760683760685,
#   'total_payments': 1414857.0,
#   'total_stock_value': 1621236.0},
#  'FOWLER PEGGY': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 1324578.0,
#   'expenses': 0.0,
#   'from_messages': 36.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 560170.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.019342359767891684,
#   'shared_receipt_with_poi': 10.0,
#   'to_messages': 517.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 0.0,
#   'total_stock_value': 1884748.0},
#  'FOY JOE': {'bonus': 0.0,
#   'deferral_payments': 181755.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 343434.0,
#   'expenses': 0.0,
#   'from_messages': 13.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.03508771929824561,
#   'shared_receipt_with_poi': 2.0,
#   'to_messages': 57.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 181755.0,
#   'total_stock_value': 343434.0},
#  'FREVERT MARK A': {'bonus': 2000000.0,
#   'deferral_payments': 6426990.0,
#   'deferred_income': -3367011.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 10433518.0,
#   'expenses': 86987.0,
#   'from_messages': 21.0,
#   'from_poi_rate': 0.2857142857142857,
#   'from_poi_to_this_person': 242.0,
#   'from_this_person_to_poi': 6.0,
#   'loan_advances': 2000000.0,
#   'long_term_incentive': 1617011.0,
#   'other': 7427621.0,
#   'poi': False,
#   'restricted_stock': 4188667.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 1060932.0,
#   'shared_poi_rate': 0.909618320610687,
#   'shared_receipt_with_poi': 2979.0,
#   'to_messages': 3275.0,
#   'to_poi_rate': 0.07389312977099237,
#   'total_payments': 17252530.0,
#   'total_stock_value': 14622185.0},
#  'FUGH JOHN L': {'bonus': 0.0,
#   'deferral_payments': 50591.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 176378.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 50591.0,
#   'total_stock_value': 176378.0},
#  'GAHN ROBERT S': {'bonus': 509870.0,
#   'deferral_payments': 73122.0,
#   'deferred_income': -1042.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 83237.0,
#   'expenses': 50080.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 76547.0,
#   'poi': False,
#   'restricted_stock': 235370.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 192008.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 900585.0,
#   'total_stock_value': 318607.0},
#  'GARLAND C KEVIN': {'bonus': 850000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 636246.0,
#   'expenses': 48405.0,
#   'from_messages': 44.0,
#   'from_poi_rate': 0.6136363636363636,
#   'from_poi_to_this_person': 10.0,
#   'from_this_person_to_poi': 27.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 375304.0,
#   'other': 60814.0,
#   'poi': False,
#   'restricted_stock': 259907.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 231946.0,
#   'shared_poi_rate': 0.8516746411483254,
#   'shared_receipt_with_poi': 178.0,
#   'to_messages': 209.0,
#   'to_poi_rate': 0.04784688995215311,
#   'total_payments': 1566469.0,
#   'total_stock_value': 896153.0},
#  'GATHMANN WILLIAM D': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 1753766.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 264013.0,
#   'restricted_stock_deferred': -72419.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 0.0,
#   'total_stock_value': 1945360.0},
#  'GIBBS DANA R': {'bonus': 0.0,
#   'deferral_payments': 504610.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 2218275.0,
#   'expenses': 0.0,
#   'from_messages': 12.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 461912.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.13609467455621302,
#   'shared_receipt_with_poi': 23.0,
#   'to_messages': 169.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 966522.0,
#   'total_stock_value': 2218275.0},
#  'GILLIS JOHN': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 9803.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 75838.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 0.0,
#   'total_stock_value': 85641.0},
#  'GLISAN JR BEN F': {'bonus': 600000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 384728.0,
#   'expenses': 125978.0,
#   'from_messages': 16.0,
#   'from_poi_rate': 0.375,
#   'from_poi_to_this_person': 52.0,
#   'from_this_person_to_poi': 6.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 71023.0,
#   'other': 200308.0,
#   'poi': True,
#   'restricted_stock': 393818.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 274975.0,
#   'shared_poi_rate': 1.0011454753722795,
#   'shared_receipt_with_poi': 874.0,
#   'to_messages': 873.0,
#   'to_poi_rate': 0.05956471935853379,
#   'total_payments': 1272284.0,
#   'total_stock_value': 778546.0},
#  'GOLD JOSEPH': {'bonus': 750000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 436515.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 304805.0,
#   'other': 819288.0,
#   'poi': False,
#   'restricted_stock': 441096.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 272880.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 2146973.0,
#   'total_stock_value': 877611.0},
#  'GRAMM WENDY L': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 119292.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 119292.0,
#   'total_stock_value': 0.0},
#  'GRAY RODNEY': {'bonus': 0.0,
#   'deferral_payments': 93585.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 365625.0,
#   'other': 680833.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 6615.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 1146658.0,
#   'total_stock_value': 0.0},
#  'HAEDICKE MARK E': {'bonus': 1150000.0,
#   'deferral_payments': 2157527.0,
#   'deferred_income': -934484.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 608750.0,
#   'expenses': 76169.0,
#   'from_messages': 1941.0,
#   'from_poi_rate': 0.03142709943328181,
#   'from_poi_to_this_person': 180.0,
#   'from_this_person_to_poi': 61.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 983346.0,
#   'other': 52382.0,
#   'poi': False,
#   'restricted_stock': 524169.0,
#   'restricted_stock_deferred': -329825.0,
#   'salary': 374125.0,
#   'shared_poi_rate': 0.4607133948615615,
#   'shared_receipt_with_poi': 1847.0,
#   'to_messages': 4009.0,
#   'to_poi_rate': 0.04489897730107259,
#   'total_payments': 3859065.0,
#   'total_stock_value': 803094.0},
#  'HANNON KEVIN P': {'bonus': 1500000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -3117011.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 5538001.0,
#   'expenses': 34039.0,
#   'from_messages': 32.0,
#   'from_poi_rate': 0.65625,
#   'from_poi_to_this_person': 32.0,
#   'from_this_person_to_poi': 21.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 1617011.0,
#   'other': 11350.0,
#   'poi': True,
#   'restricted_stock': 853064.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 243293.0,
#   'shared_poi_rate': 0.9904306220095693,
#   'shared_receipt_with_poi': 1035.0,
#   'to_messages': 1045.0,
#   'to_poi_rate': 0.03062200956937799,
#   'total_payments': 288682.0,
#   'total_stock_value': 6391065.0},
#  'HAUG DAVID L': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 475.0,
#   'from_messages': 19.0,
#   'from_poi_rate': 0.3684210526315789,
#   'from_poi_to_this_person': 4.0,
#   'from_this_person_to_poi': 7.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 2217299.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.8219895287958116,
#   'shared_receipt_with_poi': 471.0,
#   'to_messages': 573.0,
#   'to_poi_rate': 0.006980802792321117,
#   'total_payments': 475.0,
#   'total_stock_value': 2217299.0},
#  'HAYES ROBERT E': {'bonus': 0.0,
#   'deferral_payments': 7961.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 0.0,
#   'from_messages': 12.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 16.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 151418.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0992063492063492,
#   'shared_receipt_with_poi': 50.0,
#   'to_messages': 504.0,
#   'to_poi_rate': 0.031746031746031744,
#   'total_payments': 7961.0,
#   'total_stock_value': 151418.0},
#  'HAYSLETT RODERICK J': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 0.0,
#   'from_messages': 1061.0,
#   'from_poi_rate': 0.03581526861451461,
#   'from_poi_to_this_person': 35.0,
#   'from_this_person_to_poi': 38.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 346663.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.21555303888259722,
#   'shared_receipt_with_poi': 571.0,
#   'to_messages': 2649.0,
#   'to_poi_rate': 0.01321253303133258,
#   'total_payments': 0.0,
#   'total_stock_value': 346663.0},
#  'HERMANN ROBERT J': {'bonus': 700000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -280000.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 187500.0,
#   'expenses': 48357.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 150000.0,
#   'other': 416441.0,
#   'poi': False,
#   'restricted_stock': 480632.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 262663.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 1297461.0,
#   'total_stock_value': 668132.0},
#  'HICKERSON GARY J': {'bonus': 1700000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 98849.0,
#   'from_messages': 27.0,
#   'from_poi_rate': 0.037037037037037035,
#   'from_poi_to_this_person': 40.0,
#   'from_this_person_to_poi': 1.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 69223.0,
#   'other': 1936.0,
#   'poi': False,
#   'restricted_stock': 441096.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 211788.0,
#   'shared_poi_rate': 0.6818181818181818,
#   'shared_receipt_with_poi': 900.0,
#   'to_messages': 1320.0,
#   'to_poi_rate': 0.030303030303030304,
#   'total_payments': 2081796.0,
#   'total_stock_value': 441096.0},
#  'HIRKO JOSEPH': {'bonus': 0.0,
#   'deferral_payments': 10259.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 30766064.0,
#   'expenses': 77978.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 2856.0,
#   'poi': True,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 91093.0,
#   'total_stock_value': 30766064.0},
#  'HORTON STANLEY C': {'bonus': 0.0,
#   'deferral_payments': 3131860.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 5210569.0,
#   'expenses': 0.0,
#   'from_messages': 1073.0,
#   'from_poi_rate': 0.013979496738117428,
#   'from_poi_to_this_person': 44.0,
#   'from_this_person_to_poi': 15.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 2046079.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.4570212765957447,
#   'shared_receipt_with_poi': 1074.0,
#   'to_messages': 2350.0,
#   'to_poi_rate': 0.01872340425531915,
#   'total_payments': 3131860.0,
#   'total_stock_value': 7256648.0},
#  'HUGHES JAMES A': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 754966.0,
#   'expenses': 0.0,
#   'from_messages': 34.0,
#   'from_poi_rate': 0.14705882352941177,
#   'from_poi_to_this_person': 35.0,
#   'from_this_person_to_poi': 5.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 363428.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.8191933240611962,
#   'shared_receipt_with_poi': 589.0,
#   'to_messages': 719.0,
#   'to_poi_rate': 0.048678720445062586,
#   'total_payments': 0.0,
#   'total_stock_value': 1118394.0},
#  'HUMPHREY GENE E': {'bonus': 0.0,
#   'deferral_payments': 2964506.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 2282768.0,
#   'expenses': 4994.0,
#   'from_messages': 17.0,
#   'from_poi_rate': 1.0,
#   'from_poi_to_this_person': 10.0,
#   'from_this_person_to_poi': 17.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 130724.0,
#   'shared_poi_rate': 0.9296875,
#   'shared_receipt_with_poi': 119.0,
#   'to_messages': 128.0,
#   'to_poi_rate': 0.078125,
#   'total_payments': 3100224.0,
#   'total_stock_value': 2282768.0},
#  'IZZO LAWRENCE L': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 2165172.0,
#   'expenses': 28093.0,
#   'from_messages': 19.0,
#   'from_poi_rate': 0.2631578947368421,
#   'from_poi_to_this_person': 28.0,
#   'from_this_person_to_poi': 5.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 312500.0,
#   'other': 1553729.0,
#   'poi': False,
#   'restricted_stock': 3654808.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 85274.0,
#   'shared_poi_rate': 0.8810483870967742,
#   'shared_receipt_with_poi': 437.0,
#   'to_messages': 496.0,
#   'to_poi_rate': 0.056451612903225805,
#   'total_payments': 1979596.0,
#   'total_stock_value': 5819980.0},
#  'JACKSON CHARLENE R': {'bonus': 250000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 185063.0,
#   'expenses': 10181.0,
#   'from_messages': 56.0,
#   'from_poi_rate': 0.3392857142857143,
#   'from_poi_to_this_person': 25.0,
#   'from_this_person_to_poi': 19.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 2435.0,
#   'poi': False,
#   'restricted_stock': 540672.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 288558.0,
#   'shared_poi_rate': 0.45348837209302323,
#   'shared_receipt_with_poi': 117.0,
#   'to_messages': 258.0,
#   'to_poi_rate': 0.09689922480620156,
#   'total_payments': 551174.0,
#   'total_stock_value': 725735.0},
#  'JAEDICKE ROBERT': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -25000.0,
#   'director_fees': 108750.0,
#   'exercised_stock_options': 431750.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
# ...
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.9510603588907015,
#   'shared_receipt_with_poi': 583.0,
#   'to_messages': 613.0,
#   'to_poi_rate': 0.0636215334420881,
#   'total_payments': 0.0,
#   'total_stock_value': 1832468.0},
#  'SHERRIFF JOHN R': {'bonus': 1500000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 1835558.0,
#   'expenses': 0.0,
#   'from_messages': 92.0,
#   'from_poi_rate': 0.25,
#   'from_poi_to_this_person': 28.0,
#   'from_this_person_to_poi': 23.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 554422.0,
#   'other': 1852186.0,
#   'poi': False,
#   'restricted_stock': 1293424.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 428780.0,
#   'shared_poi_rate': 0.6598682146219015,
#   'shared_receipt_with_poi': 2103.0,
#   'to_messages': 3187.0,
#   'to_poi_rate': 0.008785691873235017,
#   'total_payments': 4335388.0,
#   'total_stock_value': 3128982.0},
#  'SKILLING JEFFREY K': {'bonus': 5600000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 19250000.0,
#   'expenses': 29336.0,
#   'from_messages': 108.0,
#   'from_poi_rate': 0.2777777777777778,
#   'from_poi_to_this_person': 88.0,
#   'from_this_person_to_poi': 30.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 1920000.0,
#   'other': 22122.0,
#   'poi': True,
#   'restricted_stock': 6843672.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 1111258.0,
#   'shared_poi_rate': 0.5629997242900469,
#   'shared_receipt_with_poi': 2042.0,
#   'to_messages': 3627.0,
#   'to_poi_rate': 0.0242624758753791,
#   'total_payments': 8682716.0,
#   'total_stock_value': 26093672.0},
#  'STABLER FRANK': {'bonus': 500000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 16514.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 356071.0,
#   'poi': False,
#   'restricted_stock': 511734.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 239502.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 1112087.0,
#   'total_stock_value': 511734.0},
#  'SULLIVAN-SHAKLOVITZ COLLEEN': {'bonus': 100000.0,
#   'deferral_payments': 181993.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 1362375.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 554422.0,
#   'other': 162.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 162779.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 999356.0,
#   'total_stock_value': 1362375.0},
#  'SUNDE MARTIN': {'bonus': 700000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 0.0,
#   'from_messages': 38.0,
#   'from_poi_rate': 0.34210526315789475,
#   'from_poi_to_this_person': 37.0,
#   'from_this_person_to_poi': 13.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 476451.0,
#   'other': 111122.0,
#   'poi': False,
#   'restricted_stock': 698920.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 257486.0,
#   'shared_poi_rate': 0.9690215338118625,
#   'shared_receipt_with_poi': 2565.0,
#   'to_messages': 2647.0,
#   'to_poi_rate': 0.013978088401964487,
#   'total_payments': 1545059.0,
#   'total_stock_value': 698920.0},
#  'TAYLOR MITCHELL S': {'bonus': 600000.0,
#   'deferral_payments': 227449.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 3181250.0,
#   'expenses': 0.0,
#   'from_messages': 29.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 563798.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 265214.0,
#   'shared_poi_rate': 0.5628517823639775,
#   'shared_receipt_with_poi': 300.0,
#   'to_messages': 533.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 1092663.0,
#   'total_stock_value': 3745048.0},
#  'THE TRAVEL AGENCY IN THE PARK': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 362096.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 362096.0,
#   'total_stock_value': 0.0},
#  'THORN TERENCE H': {'bonus': 0.0,
#   'deferral_payments': 16586.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 4452476.0,
#   'expenses': 46145.0,
#   'from_messages': 41.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 200000.0,
#   'other': 426629.0,
#   'poi': False,
#   'restricted_stock': 365320.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 222093.0,
#   'shared_poi_rate': 0.2744360902255639,
#   'shared_receipt_with_poi': 73.0,
#   'to_messages': 266.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 911453.0,
#   'total_stock_value': 4817796.0},
#  'TILNEY ELIZABETH A': {'bonus': 300000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -575000.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 591250.0,
#   'expenses': 0.0,
#   'from_messages': 19.0,
#   'from_poi_rate': 0.5789473684210527,
#   'from_poi_to_this_person': 10.0,
#   'from_this_person_to_poi': 11.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 275000.0,
#   'other': 152055.0,
#   'poi': False,
#   'restricted_stock': 576792.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 247338.0,
#   'shared_poi_rate': 0.8239130434782609,
#   'shared_receipt_with_poi': 379.0,
#   'to_messages': 460.0,
#   'to_poi_rate': 0.021739130434782608,
#   'total_payments': 399393.0,
#   'total_stock_value': 1168042.0},
#  'UMANOFF ADAM S': {'bonus': 788750.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 53122.0,
#   'from_messages': 18.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 12.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 288589.0,
#   'shared_poi_rate': 0.36936936936936937,
#   'shared_receipt_with_poi': 41.0,
#   'to_messages': 111.0,
#   'to_poi_rate': 0.10810810810810811,
#   'total_payments': 1130461.0,
#   'total_stock_value': 0.0},
#  'URQUHART JOHN A': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -36666.0,
#   'director_fees': 36666.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 228656.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 228656.0,
#   'total_stock_value': 0.0},
#  'WAKEHAM JOHN': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 109298.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 103773.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 213071.0,
#   'total_stock_value': 0.0},
#  'WALLS JR ROBERT H': {'bonus': 850000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 4346544.0,
#   'expenses': 50936.0,
#   'from_messages': 146.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 17.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 540751.0,
#   'other': 2.0,
#   'poi': False,
#   'restricted_stock': 1552453.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 357091.0,
#   'shared_poi_rate': 0.3204172876304024,
#   'shared_receipt_with_poi': 215.0,
#   'to_messages': 671.0,
#   'to_poi_rate': 0.02533532041728763,
#   'total_payments': 1798780.0,
#   'total_stock_value': 5898997.0},
#  'WALTERS GARETH W': {'bonus': 0.0,
#   'deferral_payments': 53625.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 1030329.0,
#   'expenses': 33785.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 87410.0,
#   'total_stock_value': 1030329.0},
#  'WASAFF GEORGE': {'bonus': 325000.0,
#   'deferral_payments': 831299.0,
#   'deferred_income': -583325.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 1668260.0,
#   'expenses': 0.0,
#   'from_messages': 30.0,
#   'from_poi_rate': 0.23333333333333334,
#   'from_poi_to_this_person': 22.0,
#   'from_this_person_to_poi': 7.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 200000.0,
#   'other': 1425.0,
#   'poi': False,
#   'restricted_stock': 388167.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 259996.0,
#   'shared_poi_rate': 0.8425,
#   'shared_receipt_with_poi': 337.0,
#   'to_messages': 400.0,
#   'to_poi_rate': 0.055,
#   'total_payments': 1034395.0,
#   'total_stock_value': 2056427.0},
#  'WESTFAHL RICHARD K': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -10800.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 51870.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 256191.0,
#   'other': 401130.0,
#   'poi': False,
#   'restricted_stock': 384930.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 63744.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 762135.0,
#   'total_stock_value': 384930.0},
#  'WHALEY DAVID A': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 98718.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 0.0,
#   'total_stock_value': 98718.0},
#  'WHALLEY LAWRENCE G': {'bonus': 3000000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 3282960.0,
#   'expenses': 57838.0,
#   'from_messages': 556.0,
#   'from_poi_rate': 0.04316546762589928,
#   'from_poi_to_this_person': 186.0,
#   'from_this_person_to_poi': 24.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 808346.0,
#   'other': 301026.0,
#   'poi': False,
#   'restricted_stock': 2796177.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 510364.0,
#   'shared_poi_rate': 0.6512709752450573,
#   'shared_receipt_with_poi': 3920.0,
#   'to_messages': 6019.0,
#   'to_poi_rate': 0.03090214321315833,
#   'total_payments': 4677574.0,
#   'total_stock_value': 6079137.0},
#  'WHITE JR THOMAS E': {'bonus': 450000.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 1297049.0,
#   'expenses': 81353.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 1085463.0,
#   'poi': False,
#   'restricted_stock': 13847074.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 317543.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 1934359.0,
#   'total_stock_value': 15144123.0},
#  'WINOKUR JR. HERBERT S': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': -25000.0,
#   'director_fees': 108579.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 1413.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 84992.0,
#   'total_stock_value': 0.0},
#  'WODRASKA JOHN': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 0.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 189583.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 189583.0,
#   'total_stock_value': 0.0},
#  'WROBEL BRUCE': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 139130.0,
#   'expenses': 0.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 0.0,
#   'total_stock_value': 139130.0},
#  'YEAGER F SCOTT': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 8308552.0,
#   'expenses': 53947.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 147950.0,
#   'poi': True,
#   'restricted_stock': 3576206.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 158403.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 360300.0,
#   'total_stock_value': 11884758.0},
#  'YEAP SOON': {'bonus': 0.0,
#   'deferral_payments': 0.0,
#   'deferred_income': 0.0,
#   'director_fees': 0.0,
#   'exercised_stock_options': 192758.0,
#   'expenses': 55097.0,
#   'from_messages': 0.0,
#   'from_poi_rate': 0.0,
#   'from_poi_to_this_person': 0.0,
#   'from_this_person_to_poi': 0.0,
#   'loan_advances': 0.0,
#   'long_term_incentive': 0.0,
#   'other': 0.0,
#   'poi': False,
#   'restricted_stock': 0.0,
#   'restricted_stock_deferred': 0.0,
#   'salary': 0.0,
#   'shared_poi_rate': 0.0,
#   'shared_receipt_with_poi': 0.0,
#   'to_messages': 0.0,
#   'to_poi_rate': 0.0,
#   'total_payments': 55097.0,
#   'total_stock_value': 192758.0}}

# %%
import sys
import pickle
sys.path.append("../tools/")

from feature_format import featureFormat, targetFeatureSplit
data = featureFormat(my_dataset, features_list, sort_keys = True, remove_NaN=True)
labels, features = targetFeatureSplit(data)

feature_columns = list(features_list)
feature_columns.pop(0)

pd.DataFrame(features, columns=feature_columns).head(3)
# Out:
#      salary  deferral_payments  total_payments  loan_advances      bonus  \
# 0  201955.0          2869717.0       4484442.0            0.0  4175000.0
# 1       0.0           178980.0        182466.0            0.0        0.0
# 2     477.0                0.0        916197.0            0.0        0.0
#
#    restricted_stock_deferred  deferred_income  total_stock_value  expenses  \
# 0                  -126027.0       -3081055.0          1729541.0   13868.0
# 1                        0.0              0.0           257817.0    3486.0
# 2                  -560222.0          -5104.0          5243487.0   56301.0
#
#    exercised_stock_options     ...       restricted_stock  director_fees  \
# 0                1729541.0     ...               126027.0            0.0
# 1                 257817.0     ...                    0.0            0.0
# 2                4046157.0     ...              1757552.0            0.0
#
#    to_messages  from_poi_to_this_person  from_messages  \
# 0       2902.0                     47.0         2195.0
# 1          0.0                      0.0            0.0
# 2        566.0                     39.0           29.0
#
#    from_this_person_to_poi  shared_receipt_with_poi  from_poi_rate  \
# 0                     65.0                   1407.0       0.029613
# 1                      0.0                      0.0       0.000000
# 2                      0.0                    465.0       0.000000
#
#    shared_poi_rate  to_poi_rate
# 0         0.484838     0.016196
# 1         0.000000     0.000000
# 2         0.821555     0.068905
#
# [3 rows x 22 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
#scaler = StandardScaler()
scaler = MinMaxScaler()

feat_scale = scaler.fit_transform(features)
feat_scale_pd = pd.DataFrame(feat_scale, columns=feature_columns)

feat_scale_pd.describe()
# Out:
#            salary  deferral_payments  total_payments  loan_advances  \
# count  144.000000         144.000000      144.000000     144.000000
# mean     0.166879           0.049711        0.021814       0.007149
# std      0.177314           0.115492        0.085425       0.083342
# min      0.000000           0.000000        0.000000       0.000000
# 25%      0.000000           0.015698        0.000962       0.000000
# 50%      0.189511           0.015698        0.009090       0.000000
# 75%      0.242669           0.017005        0.018788       0.000000
# max      1.000000           1.000000        1.000000       1.000000
#
#             bonus  restricted_stock_deferred  deferred_income  \
# count  144.000000                 144.000000       144.000000
# mean     0.084500                   0.107912         0.944731
# std      0.154144                   0.075505         0.172929
# min      0.000000                   0.000000         0.000000
# 25%      0.000000                   0.103654         0.989417
# 50%      0.037500                   0.103654         1.000000
# 75%      0.100000                   0.103654         1.000000
# max      1.000000                   1.000000         1.000000
#
#        total_stock_value    expenses  exercised_stock_options     ...       \
# count         144.000000  144.000000               144.000000     ...
# mean            0.060094    0.154638                 0.060434     ...
# std             0.125910    0.198062                 0.139614     ...
# min             0.000000    0.000000                 0.000000     ...
# 25%             0.005868    0.000000                 0.000000     ...
# 50%             0.020549    0.088222                 0.017710     ...
# 75%             0.047590    0.233116                 0.049015     ...
# max             1.000000    1.000000                 1.000000     ...
#
#        restricted_stock  director_fees  to_messages  from_poi_to_this_person  \
# count        144.000000     144.000000   144.000000               144.000000
# mean           0.199988       0.072392     0.081758                 0.073403
# std            0.116121       0.227040     0.147704                 0.140676
# min            0.000000       0.000000     0.000000                 0.000000
# 25%            0.151377       0.000000     0.000000                 0.000000
# 50%            0.170735       0.000000     0.022939                 0.007576
# 75%            0.192440       0.000000     0.107136                 0.078125
# max            1.000000       1.000000     1.000000                 1.000000
#
#        from_messages  from_this_person_to_poi  shared_receipt_with_poi  \
# count     144.000000               144.000000               144.000000
# mean        0.025305                 0.040435                 0.127262
# std         0.100966                 0.130999                 0.195126
# min         0.000000                 0.000000                 0.000000
# 25%         0.000000                 0.000000                 0.000000
# 50%         0.001218                 0.000000                 0.020648
# 75%         0.003689                 0.022989                 0.169127
# max         1.000000                 1.000000                 1.000000
#
#        from_poi_rate  shared_poi_rate  to_poi_rate
# count     144.000000       144.000000   144.000000
# mean        0.109922         0.363327     0.104317
# std         0.185935         0.372292     0.167558
# min         0.000000         0.000000     0.000000
# 25%         0.000000         0.000000     0.000000
# 50%         0.000000         0.279559     0.022782
# 75%         0.198827         0.726273     0.137655
# max         1.000000         1.000000     1.000000
#
# [8 rows x 22 columns]

# %%
### selected features: ['salary' 'bonus' 'total_stock_value' 'exercised_stock_options']

from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

##salary 	total_payments 	loan_advances 	bonus 	total_stock_value 	exercised_stock_options 	long_term_incentive
skb = SelectKBest(chi2, k=7)
selected_features = skb.fit_transform(feat_scale, labels)
feature_idx = skb.get_support()

##salary 	deferral_payments 	bonus 	deferred_income 	total_stock_value 	expenses 	exercised_stock_options
#from sklearn.feature_selection import SelectFromModel
#from sklearn.svm import LinearSVC
#svc = LinearSVC(C=0.1, dual=False)
#svc.fit(feat_scale, labels)
#model = SelectFromModel(svc, prefit=True, threshold='1.5*median')
#selected_features = model.transform(feat_scale)
#feature_idx = model.get_support()



### removing the first feature (poi), to match selected indexes
import numpy as np
feat_names = list(features_list)
poi = feat_names.pop(0)
features_np = np.array(feat_names)[feature_idx]

selected_features_pd = pd.DataFrame(selected_features, columns=features_np)
selected_features_pd.head()
# Out:
#      salary  loan_advances     bonus  total_stock_value  \
# 0  0.181735            0.0  0.521875           0.036083
# 1  0.000000            0.0  0.000000           0.006142
# 2  0.000429            0.0  0.000000           0.107571
# 3  0.240360            0.0  0.150000           0.217018
# 4  0.215675            0.0  0.050000           0.002179
#
#    exercised_stock_options  from_poi_rate  shared_poi_rate
# 0                 0.050353       0.029613         0.484283
# 1                 0.007506       0.000000         0.000000
# 2                 0.117798       0.000000         0.820615
# 3                 0.194494       0.000000         0.000000
# 4                 0.000000       0.000000         0.000000
